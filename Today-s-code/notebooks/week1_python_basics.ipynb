# %% [markdown]
# # Week 1: Python for Data Foundations
# Author: SP
# Purpose: Demonstrate Python basics for data analysis

# %%
import numpy as np
import pandas as pd

# %%
arr = np.array([10, 20, 30, 40])
print("Array:", arr)
print("Mean:", arr.mean())
print("Standard Deviation:", arr.std())

# %%
df = pd.DataFrame({"Values": arr})
df.describe()

# %%
salaries = pd.DataFrame({
    "Employee": ["A", "B", "C", "D"],
    "Salary": [50000, 60000, 75000, 80000]
})
salaries

# %%
salaries.loc[2, "Salary"] = None
salaries["Salary"].fillna(salaries["Salary"].median(), inplace=True)
salaries

# %%
print("✅ Week 1 basics complete: NumPy + Pandas + real-world example")

# %% [markdown]
# # Today-s-code
#
# ## 📌 Day 1 — Python Basics
# This notebook demonstrates:
# - NumPy arrays and basic statistics
# - Pandas DataFrames and summary statistics
# - A real-world salary dataset example
# - Handling missing values with median imputation
#
# ### 🔍 Why it matters
# Recruiters can see:
# - Awareness of industry-standard libraries (NumPy, Pandas)
# - Ability to connect code to business context (salary analysis)
# - Early focus on data cleaning, which is critical in real projects
#
# ### 📂 Files
# - `notebooks/week1_python_basics.ipynb` → Full notebook with code + outputs
